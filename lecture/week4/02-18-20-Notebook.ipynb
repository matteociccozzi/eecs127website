# %%
# %pylab inline
import numpy as np
import csv

from scipy import linalg
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
number_of_points = 1000
sigma = linspace(0, 100, num=number_of_points)
def f(sigma):
    return sigma/(llambda + sigma**2)

fig = plt.figure()

for llambda in logspace(-3,2,5):
    plt.loglog(f(sigma), label = llambda)
    
plt.loglog(1/sigma, '*')
    
plt.xlabel("\sigma (log scale)")
plt.ylabel("sigma/(lambda + sigma^2) (log scale)")
plt.legend()
plt.show()

fig1 = plt.figure()
plt.loglog(1/sigma, '*-')
# Out:
# /Users/gireeja/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# /Users/gireeja/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in true_divide
